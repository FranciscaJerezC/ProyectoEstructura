# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscaJerezC/ProyectoEstructura/blob/master/proyectoIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_crimes = pd.read_csv('crimes.csv', encoding = "ISO-8859-1", header=None)

# %%
df_crimes.head()
# Out:
#                      0                                       1     2  \
# 0                  T11  Intentional homicides and other crimes   NaN
# 1  Region/Country/Area                                     NaN  Year
# 2                    1           Total, all countries or areas  2005
# 3                    1           Total, all countries or areas  2005
# 4                    1           Total, all countries or areas  2005
#
#                                                    3      4          5  \
# 0                                                NaN    NaN        NaN
# 1                                             Series  Value  Footnotes
# 2             Intentional homicide rates per 100,000    6.3  Estimate.
# 3  Percentage of male and female intentional homi...   10.1        NaN
# 4  Percentage of male and female intentional homi...    2.4        NaN
#
#                                                    6
# 0                                                NaN
# ...

# %%
df_crimes.columns = ['Region/Country/Area', 'Nan', 'Year', 'Series', 'Value', 'Footnotes', 'Source']
df_crimes
# Out:
#       Region/Country/Area                                     Nan  Year  \
# 0                     T11  Intentional homicides and other crimes   NaN
# 1     Region/Country/Area                                     NaN  Year
# 2                       1           Total, all countries or areas  2005
# 3                       1           Total, all countries or areas  2005
# 4                       1           Total, all countries or areas  2005
# ...                   ...                                     ...   ...
# 3738                  716                                Zimbabwe  2008
# 3739                  716                                Zimbabwe  2008
# 3740                  716                                Zimbabwe  2008
# 3741                  716                                Zimbabwe  2010
# 3742                  716                                Zimbabwe  2012
#
#                                                  Series  Value  Footnotes  \
# ...

# %%
df_crimes.head()
# Out:
#    Region/Country/Area                                     Nan  Year  \
# 0                  T11  Intentional homicides and other crimes   NaN
# 1  Region/Country/Area                                     NaN  Year
# 2                    1           Total, all countries or areas  2005
# 3                    1           Total, all countries or areas  2005
# 4                    1           Total, all countries or areas  2005
#
#                                               Series  Value  Footnotes  \
# 0                                                NaN    NaN        NaN
# 1                                             Series  Value  Footnotes
# 2             Intentional homicide rates per 100,000    6.3  Estimate.
# 3  Percentage of male and female intentional homi...   10.1        NaN
# 4  Percentage of male and female intentional homi...    2.4        NaN
#
#                                               Source
# 0                                                NaN
# ...

# %%
df_crimes = df_crimes.drop(0)
df_crimes.head()
# Out:
#    Region/Country/Area                            Nan  Year  \
# 1  Region/Country/Area                            NaN  Year
# 2                    1  Total, all countries or areas  2005
# 3                    1  Total, all countries or areas  2005
# 4                    1  Total, all countries or areas  2005
# 5                    1  Total, all countries or areas  2010
#
#                                               Series  Value  Footnotes  \
# 1                                             Series  Value  Footnotes
# 2             Intentional homicide rates per 100,000    6.3  Estimate.
# 3  Percentage of male and female intentional homi...   10.1        NaN
# 4  Percentage of male and female intentional homi...    2.4        NaN
# 5             Intentional homicide rates per 100,000    6.0  Estimate.
#
#                                               Source
# 1                                             Source
# 2  United Nations Office on Drugs and Crime (UNOD...
# ...

# %%
df_crimes = df_crimes.drop(1)
df_crimes.head()
# Out:
#   Region/Country/Area                            Nan  Year  \
# 2                   1  Total, all countries or areas  2005
# 3                   1  Total, all countries or areas  2005
# 4                   1  Total, all countries or areas  2005
# 5                   1  Total, all countries or areas  2010
# 6                   1  Total, all countries or areas  2010
#
#                                               Series Value  Footnotes  \
# 2             Intentional homicide rates per 100,000   6.3  Estimate.
# 3  Percentage of male and female intentional homi...  10.1        NaN
# 4  Percentage of male and female intentional homi...   2.4        NaN
# 5             Intentional homicide rates per 100,000   6.0  Estimate.
# 6  Percentage of male and female intentional homi...   9.6        NaN
#
#                                               Source
# 2  United Nations Office on Drugs and Crime (UNOD...
# 3  United Nations Office on Drugs and Crime (UNOD...
# ...

# %%
df_crimes.shape
# Out:
# (3741, 7)

# %%
df_crimes.dtypes
# Out:
# Region/Country/Area    object
# Nan                    object
# Year                   object
# Series                 object
# Value                  object
# Footnotes              object
# Source                 object
# dtype: object

# %%
# %matplotlib inline
import matplotlib
